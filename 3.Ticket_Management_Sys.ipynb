# %% [markdown]
# LAB 3

# %% [markdown]
# Task 1.Store Passenger details using Variables

# %%
passenger_name = "Rohit Sharma"
passenger_age = 39
gender = "Male"
mobile_number = 9876543210

print("Passenger Name : ",passenger_name)
print("Passenger Age : ",passenger_age)
print("Gender : ",gender)
print("Mobile Number : ",mobile_number)
# Out:
# Passenger Name :  Rohit Sharma
# Passenger Age :  39
# Gender :  Male
# Mobile Number :  9876543210

# %% [markdown]
# Task 2 : Store Ticket Price and Seat Number

# %%
train_number = "Rajdhani Express"
seat_number ="B2-45"
ticket_price = 2450
journey_date ="25-May-2026"

print("Train Name : ",train_number)
print("Seat Number : ",seat_number)
print("Ticket Price : ",ticket_price)
print("Journey Date : ",journey_date)
# Out:
# Train Name :  Rajdhani Express
# Seat Number :  B2-45
# Ticket Price :  2450
# Journey Date :  25-May-2026

# %%
passenger_name = input("Enter Your Name: ")
print(type(passenger_name))
# Out:
# <class 'str'>

# %%
ticket_price=int(input("Enter price of a ticket"))
type(ticket_price)
# Out:
# int

# %% [markdown]
# Task 3: Perform Ticket Fare Calculations

# %%
number_of_passengers = 3
ticket_price = 2450

total_fare = number_of_passengers * ticket_price
print(total_fare)
# Out:
# 7350

# %% [markdown]
# Task 4: Calculate GST on Ticket Fare

# %%
gst_percentage = 5

gst_amount= (total_fare * gst_percentage)/100
print("GST Amount = ",gst_amount)
# Out:
# GST Amount =  367.5

# %%
final_amount = total_fare + gst_amount
print("Final Payable Amount :", final_amount)
# Out:
# Final Payable Amount : 7717.5

# %%
print("----------- Indian Railways Ticket -----------")
print("Passenger Name :", passenger_name)
print("Train Name 	:", train_number)
print("Seat Number	:", seat_number)
print("Journey Date   :", journey_date)
print("Passengers 	:", number_of_passengers)
print("Ticket Fare	:", total_fare)
print("GST Amount 	:", gst_amount)
print("Final Amount   :", final_amount)
print("----------------------------------------------")
# Out:
# ----------- Indian Railways Ticket -----------
# Passenger Name : asdasdas
# Train Name 	: Rajdhani Express
# Seat Number	: B2-45
# Journey Date   : 25-May-2026
# Passengers 	: 3
# Ticket Fare	: 7350
# GST Amount 	: 367.5
# Final Amount   : 7717.5
# ----------------------------------------------

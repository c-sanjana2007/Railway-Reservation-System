# %% [markdown]
# PRACTICE

# %%
age=int(input("Enter Your Age"))

if age>=18:
    print("You are eligible for License")
else:
    print("You are age is not eeligible for license")
# Out:
# You are age is not eeligible for license

# %%
my=[True,8,"isha"]
for i in range(len(my)):
    print(i,my[i])
# Out:
# 0 True
# 1 8
# 2 isha

# %%
li=[]
length=int(input("Enter your length"))

for i in range(length):
    item=input(f"Enter your {i} item")
    li.append(item)
print(li)
# Out:
# ['jam', 'san']

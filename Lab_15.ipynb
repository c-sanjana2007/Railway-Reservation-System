# %% [markdown]
# Constructor and Destructor

# %% [markdown]
# Constructor

# %%
class Car:

    def __init__(self):
        print("Constructor Called")

car1 = Car()

# %%
class Car:

    def __init__(self, company, color):
        self.company = company
        self.color = color

    def show(self):
        print(self.company)
        print(self.color)

car1 = Car("Tesla", "Red")
car1.show()
# Out:
# Tesla
# Red

# %%
class Car:

    def __del__(self):
        print("Destructor Called")

car1 = Car()

del car1
# Out:
# Destructor Called

# %% [markdown]
# Task 1: Create Constructor

# %%
class RailwayReservation:

    def __init__(self,passenger_name,train_name,seat_number):
        self.passenger_name = passenger_name
        self.train_name = train_name
        self.seat_number = seat_number
        
ticket1 = RailwayReservation(
    "Rahul Sharma",
    "Rajdhani Express",
    "A1-21")
    
print(ticket1.passenger_name)
print(ticket1.train_name)
print(ticket1.seat_number)
# Out:
# Rahul Sharma
# Rajdhani Express
# A1-21

# %% [markdown]
# Task 2: Handle Multiple Reservation Object

# %%
class Reservation:

    def __init__(self,passenger_name,seat_number):
        self.passenger_name = passenger_name
        self.seat_number = seat_number
 
    def display_ticket(self):
        print("Passenger :", self.passenger_name)
        print("Seat Number :", self.seat_number)
        print("-----------------------------------")
        
ticket1 = Reservation("Rahul Sharma","B1-21")
ticket2 = Reservation("Priya Singh","B1-22")
ticket3 = Reservation("Amit Verma","B1-23")

ticket1.display_ticket()
ticket2.display_ticket()
ticket3.display_ticket()
# Out:
# Passenger : Rahul Sharma
# Seat Number : B1-21
# -----------------------------------
# Passenger : Priya Singh
# Seat Number : B1-22
# -----------------------------------
# Passenger : Amit Verma
# Seat Number : B1-23
# -----------------------------------

# %% [markdown]
# Task 3: Build Final System & Use Destructor

# %%
class RailwayReservation:

    def __init__(self,passenger_name,train_name,seat_number,ticket_price):
        self.passenger_name = passenger_name
        self.train_name = train_name
        self.seat_number = seat_number
        self.ticket_price = ticket_price
        print("Reservation Created Successfully")

    def display_ticket(self):
        print("===================================")
        print(" Railway Reservation Ticket ")
        print("===================================")
        print("Passenger Name :", self.passenger_name)
        print("Train Name :", self.train_name)
        print("Seat Number :", self.seat_number)
        print("Ticket Price :", self.ticket_price)

    def __del__(self):
        print("Reservation Cancelled")

# %%
ticket1 = RailwayReservation("Neha Kapoor","Rajdhani Express","A1-25",2450)
# Out:
# Reservation Created Successfully

# %%
ticket1.display_ticket()
# Out:
# ===================================
#  Railway Reservation Ticket
# ===================================
# Passenger Name : Neha Kapoor
# Train Name : Rajdhani Express
# Seat Number : A1-25
# Ticket Price : 2450

# %%
del ticket1
# Out:
# Reservation Cancelled
